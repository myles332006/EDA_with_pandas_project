# %% [markdown]
# # Final Project Submission
# By: Myles Imbayi
#
# Student Pace: Part-Time
#
# Scheduled project review date/time: 8/1/2025
#
# Instructor Name: Noah Kandie
#
# Blog post URL: https://github.com/myles332006/EDA_with_pandas_project

# %% [markdown]
# # **EDA WITH PANDAS PROJECT**

# %% [markdown]
# **Let's start of by importing the libraries.**

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Let's now open the movie gross file**

# %%
df = pd.read_csv("bom.movie_gross.csv")
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df.info() #checking for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3387 entries, 0 to 3386
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   title           3387 non-null   object
#  1   studio          3382 non-null   object
#  2   domestic_gross  3359 non-null   float64
#  3   foreign_gross   2037 non-null   object
#  4   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 132.4+ KB

# %% [markdown]
# **Let's open the Title basics file**

# %%
df2 = pd.read_csv("title.basics.csv")
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df2.info() #checking for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146143 non-null  object
#  2   original_title   146122 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB

# %% [markdown]
# **Lastly let's open the Title ratings file**

# %%
df3 = pd.read_csv("title.ratings.csv")
df3
# Out:
#            tconst  averagerating  numvotes
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73851   tt9805820            8.1        25
# 73852   tt9844256            7.5        24
# 73853   tt9851050            4.7        14
# 73854   tt9886934            7.0         5
# 73855   tt9894098            6.3       128
#
# [73856 rows x 3 columns]

# %%
df3.info() #checking for missing values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB

# %% [markdown]
# **DATA CLEANING**

# %% [markdown]
# # DF1 Cleaning

# %%
#Checking for null values for the dataframe

df.isnull().sum()
# Out:
# title                0
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# **Replacing the null values.**

# %%
#finding the specific rows that contain the null values

df[df.isnull().any(axis = 1)]
# Out:
#                                        title      studio  domestic_gross  \
# 210            Outside the Law (Hors-la-loi)         NaN         96900.0
# 222                                  Flipped          WB       1800000.0
# 230               It's a Wonderful Afterlife         UTV             NaN
# 254   The Polar Express (IMAX re-issue 2010)          WB        673000.0
# 267                           Tiny Furniture         IFC        392000.0
# ...                                      ...         ...             ...
# 3382                               The Quake       Magn.          6200.0
# 3383             Edward II (2018 re-release)          FM          4800.0
# 3384                                El Pacto        Sony          2500.0
# 3385                                The Swan  Synergetic          2400.0
# 3386                       An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# 210        3300000  2010
# 222            NaN  2010
# ...

# %%
df['studio'] = df['studio'].fillna('Unknown')
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df['domestic_gross'] = df['domestic_gross'].fillna(0)
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %%
df['foreign_gross'] = df['foreign_gross'].fillna(0)
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year
# ...

# %% [markdown]
# **Now let's recheck and see if there's any missing values.**

# %%
df.isnull().sum()
# Out:
# title             0
# studio            0
# domestic_gross    0
# foreign_gross     0
# year              0
# dtype: int64

# %% [markdown]
# # DF2 cleaning

# %%
df2.isnull().sum()
# Out:
# tconst                 0
# primary_title          1
# original_title        22
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
df2[df2.isnull().any(axis = 1)]
# Out:
#            tconst                                      primary_title  \
# 3       tt0069204                                    Sabse Bada Sukh
# 6       tt0112502                                            Bigfoot
# 8       tt0139613                                         O Silêncio
# 16      tt0187902  How Huang Fei-hong Rescued the Orphan from the...
# 21      tt0250404                                          Godfather
# ...           ...                                                ...
# 146138  tt9916428                                The Secret of China
# 146140  tt9916622        Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                                    Dankyavar Danka
# 146142  tt9916730                                             6 Gunn
# 146143  tt9916754                     Chico Albuquerque - Revelações
#
#                                            original_title  start_year  \
# ...

# %%
df2['genres'] = df2['genres'].fillna('Unknown')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df2['runtime_minutes'] = df2['runtime_minutes'].fillna(0)
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df2['original_title'] = df2['original_title'].fillna('Unknown')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %%
df2['primary_title'] = df2['primary_title'].fillna('Unknown')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 2       tt0069049                   The Other Side of the Wind
# 3       tt0069204                              Sabse Bada Sukh
# 4       tt0100275                     The Wandering Soap Opera
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 1                                   Ashad Ka Ek Din        2019
# ...

# %% [markdown]
# **Now let's recheck and see if we have any missing values.**

# %%
df2.isnull().sum()
# Out:
# tconst             0
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %% [markdown]
# # DF3 cleaning

# %%
df3.isnull().sum()
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
#  **Luckily df3 doesn't contain any missing or null values hence no need to clean any data.**

# %% [markdown]
# **Checking for duplicates**

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3382    False
# 3383    False
# 3384    False
# 3385    False
# 3386    False
# Length: 3387, dtype: bool

# %%
df2.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 146139    False
# 146140    False
# 146141    False
# 146142    False
# 146143    False
# Length: 146144, dtype: bool

# %%
df3.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 73851    False
# 73852    False
# 73853    False
# 73854    False
# 73855    False
# Length: 73856, dtype: bool

# %% [markdown]
# # How old are each of these movies?

# %%
df.head(15)
# Out:
#                                                 title studio  domestic_gross  \
# 0                                         Toy Story 3     BV     415000000.0
# 1                          Alice in Wonderland (2010)     BV     334200000.0
# 2         Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# 3                                           Inception     WB     292600000.0
# 4                                 Shrek Forever After   P/DW     238700000.0
# 5                          The Twilight Saga: Eclipse   Sum.     300500000.0
# 6                                          Iron Man 2   Par.     312400000.0
# 7                                             Tangled     BV     200800000.0
# 8                                       Despicable Me   Uni.     251500000.0
# 9                            How to Train Your Dragon   P/DW     217600000.0
# 10                         Clash of the Titans (2010)     WB     163200000.0
# ...

# %%
df['age'] = 2025 - df['year']
df
# Out:
#                                             title      studio  domestic_gross  \
# 0                                     Toy Story 3          BV     415000000.0
# 1                      Alice in Wonderland (2010)          BV     334200000.0
# 2     Harry Potter and the Deathly Hallows Part 1          WB     296000000.0
# 3                                       Inception          WB     292600000.0
# 4                             Shrek Forever After        P/DW     238700000.0
# ...                                           ...         ...             ...
# 3382                                    The Quake       Magn.          6200.0
# 3383                  Edward II (2018 re-release)          FM          4800.0
# 3384                                     El Pacto        Sony          2500.0
# 3385                                     The Swan  Synergetic          2400.0
# 3386                            An Actor Prepares       Grav.          1700.0
#
#      foreign_gross  year  age
# ...

# %%
df.describe()
# Out:
#        domestic_gross         year          age
# count    3.387000e+03  3387.000000  3387.000000
# mean     2.850821e+07  2013.958075    11.041925
# std      6.675575e+07     2.478141     2.478141
# min      0.000000e+00  2010.000000     7.000000
# 25%      1.115000e+05  2012.000000     9.000000
# 50%      1.300000e+06  2014.000000    11.000000
# 75%      2.750000e+07  2016.000000    13.000000
# max      9.367000e+08  2018.000000    15.000000

# %%
sns.boxplot(data = df, showfliers= False)
plt.title('Boxplot of the dataframe')
plt.show()

# %% [markdown]
# **Now that we've cleaned the dataframe, let's go ahead and visualize the data.**

# %%
df.describe()
# Out:
#        domestic_gross         year
# count    3.387000e+03  3387.000000
# mean     2.850821e+07  2013.958075
# std      6.675575e+07     2.478141
# min      0.000000e+00  2010.000000
# 25%      1.115000e+05  2012.000000
# 50%      1.300000e+06  2014.000000
# 75%      2.750000e+07  2016.000000
# max      9.367000e+08  2018.000000

# %%
#Let's see if the dataframe contains outliers
sns.boxplot(data = df)
plt.title('Boxplot of the dataframe')
plt.show()

# %%
#Matplotlib version

df.plot(kind= 'box')
# Out:
# <Axes: >

# %% [markdown]
# **Now let's remove the outliers**

# %%
df.plot(kind= 'box', showfliers = False)
plt.title('Boxplot of the dataframe')
plt.show()

# %% [markdown]
# # 1) Which year has the most successful movie releases?

# %%
x1 = df['year'].value_counts()
x1
# Out:
# year
# 2015    450
# 2016    436
# 2012    400
# 2011    399
# 2014    395
# 2013    350
# 2010    328
# 2017    321
# 2018    308
# Name: count, dtype: int64

# %%
x1.plot(kind = 'bar')
plt.title('Years of movie release')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **From the histogram we can easily interpret the mode of the years of the movie releases, in which this case is 2015.**

# %%
IQR = x1.quantile(0.75) - x1.quantile(0.25)
IQR
# Out:
# np.float64(72.0)

# %% [markdown]
# # 2) Which movies have been the most profitable over the years?

# %%
plt.pie(df['foreign_gross'].head(7), labels = df['title'].head(7), autopct = '%1.1f%%')
plt.title('The most profitable movies in the World.')
plt.show()

# %% [markdown]
# # 3) What genre is commonly produced in movies?

# %%
df2['genres'] = df2['genres'].str.split(',') #Let's seperate many genres from one column
df2 = df2.explode('genres')
df2
# Out:
#            tconst                                primary_title  \
# 0       tt0063540                                    Sunghursh
# 0       tt0063540                                    Sunghursh
# 0       tt0063540                                    Sunghursh
# 1       tt0066787              One Day Before the Rainy Season
# 1       tt0066787              One Day Before the Rainy Season
# ...           ...                                          ...
# 146139  tt9916538                          Kuambil Lagi Hatiku
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro
# 146141  tt9916706                              Dankyavar Danka
# 146142  tt9916730                                       6 Gunn
# 146143  tt9916754               Chico Albuquerque - Revelações
#
#                                      original_title  start_year  \
# 0                                         Sunghursh        2013
# 0                                         Sunghursh        2013
# ...

# %%
df2['genres'].value_counts().head(25)
# Out:
# genres
# Documentary    51640
# Drama          49883
# Comedy         25312
# Thriller       11883
# Horror         10805
# Action         10335
# Romance         9372
# Biography       8722
# Crime           6753
# Adventure       6465
# Family          6227
# History         6225
# Unknown         5408
# Mystery         4659
# Music           4314
# Fantasy         3516
# Sci-Fi          3365
# Animation       2799
# Sport           2234
# News            1551
# Musical         1430
# War             1405
# Western          467
# Reality-TV        98
# Talk-Show         50
# Name: count, dtype: int64

# %%
plt.figure(figsize= (14,7))
ax2 = sns.countplot(x = 'genres', data = df2, palette = 'magma', order = df2['genres'].value_counts().index, hue = "genres")
plt.xticks(rotation = 90)
plt.ylabel('Frequency')
plt.xlabel('Genres')
plt.title('Most produced genres')
plt.show()

# %% [markdown]
# # 4) What would the distribution look like for the average rating for movies?

# %%
df3['averagerating'].hist(color= 'green', grid= False, figsize= (10,8), bins = df3['averagerating'].nunique(), density = True)
plt.title('Average rating distribution')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Comparing Rating and the number of votes**

# %%
sns.lineplot(data= df3, y = df3['numvotes'].head(25), x = df3['averagerating'].head(25))
plt.title('Rating vs Number of votes')
plt.xlabel('Number of votes')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# # What is the correlation between the Average Rating and the number of votes?

# %%
cov = df3['averagerating'].corr(df3['numvotes'])
cov
# Out:
# np.float64(0.04447809440198376)

# %%
plt.figure(figsize= (10,8))
sns.heatmap(df3.corr(numeric_only= True), annot= True, cmap= 'magma')
plt.title('Correlation heatmap')
plt.show()
#

# %%
sns.regplot(y= df3['averagerating'], x= df3['numvotes'])
plt.title('Rating vs Number of votes')
plt.xlabel('Number of votes')
plt.ylabel('Rating')
plt.show()

# %% [markdown]
# # Now let's see the correlation between Domestic Gross and the Year of publishment.

# %%
cov1 = df['domestic_gross'].corr(df['year'])
cov1
# Out:
# np.float64(0.020362159049417294)

# %%
sns.heatmap(df.corr(numeric_only= True), annot= True, cmap= 'magma')
plt.title('Correlation heatmap')
plt.show()

# %%
plt.scatter(df['domestic_gross'], df['year'])
plt.title('Domestic Gross vs Year')
plt.xlabel('Year')
plt.ylabel('Domestic Gross')
plt.show()

# %% [markdown]
# # Lastly which studio is the most beneficial for recording movies?

# %%
best_studio = df['studio'].value_counts().head(10)
best_studio
# Out:
# studio
# IFC      166
# Uni.     147
# WB       140
# Fox      136
# Magn.    136
# SPC      123
# Sony     110
# BV       106
# LGF      103
# Par.     101
# Name: count, dtype: int64

# %%
plt.pie(best_studio, labels = best_studio.index, autopct = '%1.1f%%')
plt.title('The best studios for recording movies.')
plt.show()

# %% [markdown]
# **Conclusion: IFC studios is the most popular studio and it's known for producing the most frequent movies around the world.**
